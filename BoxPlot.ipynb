# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_files = ['Intention/Cleaned Data/CBO_Cleaned.csv',
             'Intention/Cleaned Data/DIT_Cleaned.csv',
             'Intention/Cleaned Data/LCOM_Cleaned.csv',
             'Intention/Cleaned Data/LOC_Cleaned.csv',
             'Intention/Cleaned Data/NOC_Cleaned.csv',
             'Intention/Cleaned Data/RFC_Cleaned.csv',
             'Intention/Cleaned Data/WMC_Cleaned.csv'
            ]

fig, ax = plt.subplots()
for csv_file in csv_files:
    
    file_path = os.path.join(os.getcwd(),csv_file)
    df = pd.read_csv(file_path)
    
    ax.boxplot(df['Before'], labels=[csv_file[:-4]])
    
ax.set_ylabel('Before Data')
ax.set_title('BOX PLOT')
plt.show()
